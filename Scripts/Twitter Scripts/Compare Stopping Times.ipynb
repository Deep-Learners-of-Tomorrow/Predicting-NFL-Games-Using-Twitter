# %%
import pandas as pd
import numpy as np
header_list = ["tweet_ID", "tweet_time","team","opponent", "week", "home_or_away","score","opponent_score","point_spread","over_under"]
df = pd.read_csv('nfl-tweets-v1.0/tweets.nfl.2011.weekly.csv', names=header_list)
tweets = df["tweet_ID"].tolist()

# %%
#2010
with open('2011lastwrite.txt', 'r') as readfile:
    f=readfile.readlines()
last_tweet = int(f[-1].split('\t')[0])
last_tweet_index = tweets.index(last_tweet)
with open('2011lastwrite(reverse).txt', 'r') as readfile:
    f=readfile.readlines()
last_tweet = int(f[-1].split('\t')[0])
last_tweet_index_reverse = tweets.index(last_tweet) + 1

# %%
print(last_tweet_index,last_tweet_index_reverse)

# %%
print(last_tweet_index,last_tweet_index_reverse)
# Out:
# 286706 238753

# %%
print(len(tweets))
# Out:
# 185709

# %%
291953283436545 #start of error

# %%
999725155221504 #end of error

# %%
import pandas as pd
a = pd.read_csv("2010tweettext.txt",header = None, sep='\t',error_bad_lines=False)
b = pd.read_csv("2010tweettext(reverse).txt",header = None, sep='\t',error_bad_lines=False)
# then use concat?
# Out:
# b'Skipping line 3052: expected 2 fields, saw 3\nSkipping line 9654: expected 2 fields, saw 4\nSkipping line 32533: expected 2 fields, saw 3\nSkipping line 39832: expected 2 fields, saw 3\nSkipping line 55467: expected 2 fields, saw 3\nSkipping line 72215: expected 2 fields, saw 3\nSkipping line 73989: expected 2 fields, saw 3\nSkipping line 75357: expected 2 fields, saw 3\nSkipping line 78180: expected 2 fields, saw 3\nSkipping line 84434: expected 2 fields, saw 3\nSkipping line 87083: expected 2 fields, saw 3\nSkipping line 88713: expected 2 fields, saw 4\nSkipping line 92599: expected 2 fields, saw 3\nSkipping line 94905: expected 2 fields, saw 3\nSkipping line 95823: expected 2 fields, saw 3\nSkipping line 100512: expected 2 fields, saw 3\nSkipping line 102775: expected 2 fields, saw 3\nSkipping line 103001: expected 2 fields, saw 5\nSkipping line 110287: expected 2 fields, saw 3\nSkipping line 113511: expected 2 fields, saw 3\nSkipping line 118673: expected 2 fields, saw 3\nSkipp
# ...

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
def get_sentiment(tweet):
  analyzer = SentimentIntensityAnalyzer()
  return analyzer.polarity_scores(tweet)['compound']
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/stanierc17/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# %%time
tweets2010['sent'] = tweets2010['text'].apply(lambda x: get_sentiment(str(x)))
# Out:
# CPU times: user 29min 51s, sys: 37.6 s, total: 30min 28s
# Wall time: 32min 30s

# %%
sent = tweets2010['sent'].tolist()

# %%
print(a.groupby('sent').count().to_string())
# Out:
#           id  text
# sent
# -0.8176    1     1
# -0.8122    1     1
# -0.8074    1     1
# -0.8020    1     1
# -0.7906    1     1
# -0.7721    1     1
# -0.7500    1     1
# -0.7450    2     2
# -0.7430    4     4
# -0.7351    1     1
# -0.7269    1     1
# -0.6908    1     1
# -0.6808    1     1
# -0.6797    1     1
# -0.6739    1     1
# -0.6715    1     1
# -0.6696    1     1
# -0.6633    1     1
# -0.6597    1     1
# -0.6437    1     1
# -0.6259    1     1
# -0.6249    1     1
# -0.6239    1     1
# -0.6124    1     1
# -0.6103    1     1
# -0.5994    2     2
# -0.5859    1     1
# -0.5848    1     1
# -0.5835    1     1
# -0.5789    1     1
# -0.5719    2     2
# -0.5707    1     1
# -0.5574    8     8
# -0.5563    1     1
# -0.5542    1     1
# -0.5423    3     3
# -0.5400    1     1
# -0.5399    1     1
# -0.5267    1     1
# -0.5256    1     1
# -0.5255    2     2
# -0.5112    1     1
# -0.5106    1     1
# -0.4995    1     1
# -0.4981    1     1
# -0.4973    1     1
# ...

# %%
tweets2010
# Out:
#                       id                                               text
# 0            22662042404  Can someone please tell me WTF the #Seahawks a...
# 1            22662135903  Q&A with Todd Haley - 8/31 #NFL #chiefs http:/...
# 2            22662138503  PFW Blog: Bodden done for the year #NFL #patri...
# 3            22662142404  Bomar the backup for Giants, for now #NFL #gia...
# 4            22662229101  #Packers made the right moves 2day. Tough deci...
# ...                  ...                                                ...
# 47241  19541631682220032  @Rozzell32 yea he do need to gone and drop dat...
# 47242  19541635893297152                 @seatownsports PLAYOFFS. #seahawks
# 47243  19541786770804737  Gonna eat this sammy, smoke fat blunt and play...
# 47244  19541799517298688  since atlanta is home of @cnn, would be cool i...
# 47245  19541807700381696  RT @NickyDiamonds: Black/Green @Currensy_Spitt...
#
# [172958 rows x 2 columns]

# %%
type(get_sentiment('hello'))
# Out:
# float

# %%
sent.count(0.0)
# Out:
# 69704

# %%
len(sent)
# Out:
# 172958

# %%
# load additional module
import pickle

with open('2010missing_tweets', 'rb') as filehandle:
    # read the data as binary data stream
    missing_tweets = pickle.load(filehandle)

# %%
missing_tweets
# Out:
# ['24392221907',
#  '26120535807',
#  '27732054256',
#  '6702854446260224',
#  '12221191439781888',
#  '19754697975930880',
#  '28569795588',
#  '8554539028324352',
#  '29627681986',
#  '5715729466789888',
#  '28560358965',
#  '24748125908',
#  '24959574700',
#  '4144152803549184',
#  '22665680004',
#  '19595927073325057',
#  '14519892317306880',
#  '20984321170997248',
#  '26555599202',
#  '24895791205',
#  '25679428007',
#  '27593340215',
#  '6389124827185152',
#  '8641600334856193',
#  '1292504192262144',
#  '17807035470970880',
#  '24706796702',
#  '13137290226302976',
#  '25676756703',
#  '1721447491833856',
#  '25033682504',
#  '7854539168284672',
#  '29396207956',
#  '28717392490',
#  '683894202441728',
#  '27365796768',
#  '24762508102',
#  '19184746818961408',
#  '24587782907',
#  '18059243106074624',
#  '28718718513',
#  '28937004484',
#  '25310206307',
#  '29005768283',
#  '28670661108',
#  '2866102258372608',
#  '1295943743836161',
#  '29418445786',
#  '26616868700',
# ...

# %%
header_list = ["tweet_ID", "tweet_text"]
tweets_2010 = pd.read_csv("2010alltweets.txt", names=header_list, sep="\t")

# %%
a = tweets_2010.head()

# %%
b = add_sentiment(a)
# Out:
# <ipython-input-22-9abf82479949>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sentiment'] = df['tweet_text'].apply(lambda x: get_sentiment(str(x)))

# %%
pd.set_option('display.max_colwidth', -1)
b
# Out:
# <ipython-input-27-55a8d4a31ccb>:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
#       tweet_ID  \
# 0  22662042404
# 1  22662135903
# 2  22662138503
# 3  22662142404
# 4  22662229101
#
#                                                                                                                                      tweet_text  \
# 0  Can someone please tell me WTF the #Seahawks are doing? #retards
# 1  Q&A with Todd Haley - 8/31 #NFL #chiefs http://tinyurl.com/333m7np
# 2  PFW Blog: Bodden done for the year #NFL #patriots http://tinyurl.com/34glgfb
# 3  Bomar the backup for Giants, for now #NFL #giants http://tinyurl.com/39fmylf
# 4  #Packers made the right moves 2day. Tough decisions in week 7, but Peprah will help ST's & Starks may b ready by then, which would b a boost
#
#    sentiment
# 0 -0.4995
# 1  0.0000
# ...

# %%
# Clean the tweets
b['tweet_text'] = b['tweet_text'].apply(cleanTxt)
# Out:
# <ipython-input-31-bc71563caac6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b['tweet_text'] = b['tweet_text'].apply(cleanTxt)

# %%
b
# Out:
#       tweet_ID  \
# 0  22662042404
# 1  22662135903
# 2  22662138503
# 3  22662142404
# 4  22662229101
#
#                                                                                                                                     tweet_text  \
# 0  Can someone please tell me WTF the Seahawks are doing? retards
# 1  Q&A with Todd Haley - 8/31 NFL chiefs
# 2  PFW Blog: Bodden done for the year NFL patriots
# 3  Bomar the backup for Giants, for now NFL giants
# 4  Packers made the right moves 2day. Tough decisions in week 7, but Peprah will help ST's & Starks may b ready by then, which would b a boost
#
#    sentiment
# 0 -0.4995
# 1  0.0000
# 2  0.0000
# 3  0.0000
# 4  0.8779

# %% [markdown]
# ### Functions and Imports

# %%
import re
import nltk
#from textblob import TextBlob
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')

def get_sentiment(tweet):
    analyzer = SentimentIntensityAnalyzer()
    return analyzer.polarity_scores(tweet)['compound']

def add_sentiment(df):
    df['sentiment'] = df['text'].apply(lambda x: get_sentiment(str(x)))
    return df

def cleanTxt(text):
    text = re.sub('@[A-Za-z0–9]+', '', text) #Removing @mentions
    text = re.sub('#', '', text) # Removing '#' hash tag
    text = re.sub('RT[\s]+', '', text) # Removing RT
    text = re.sub('https?:\/\/\S+', '', text) # Removing hyperlink
    return text

def make_twitter_df(year):
    year = str(year)
    tweets_file_name = year+"alltweets.txt"
    tweets_header_list = ['id','text']
    tweets_df = pd.read_csv(tweets_file_name, names=tweets_header_list, sep='\t',error_bad_lines=False)
    tweets_df = tweets_df.dropna()
    tweets_df['text'] = tweets_df['text'].apply(cleanTxt)
    tweets_df['id'] = tweets_df['id'].apply(int)
    
    data_header_list = ["id", "tweet_time","team","opponent", "week", "home_or_away","score","opponent_score","point_spread","over_under"]
    data_df = pd.read_csv('nfl-tweets-v1.0/tweets.nfl.'+year+'.weekly.csv', names=data_header_list)
    
    combined_df = pd.merge(data_df,tweets_df,on='id').dropna()
    sent_df = add_sentiment(combined_df)
    
    final_df = sent_df[["team", "week","sentiment","text"]]
    final_df = final_df.groupby(['team','week'],as_index=False)['sentiment'].mean()

    return final_df
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/stanierc17/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
df = make_twitter_df(2011)

# %%
df.to_csv("2011sentiment.csv",index=False)

# %% [markdown]
# # Step 1: Prepare Dataframe

# %%
# The only thing you need to change for the different datasets
year = "2010"

# Here I'm putting everything into a dataframe and cleaning the text
tweets_file_name = year+"alltweets.txt"
tweets_header_list = ['id','text']
tweets_df = pd.read_csv(tweets_file_name, names=tweets_header_list, sep='\t',error_bad_lines=False)
tweets_df = tweets_df.dropna()
tweets_df['text'] = tweets_df['text'].apply(cleanTxt)
tweets_df['id'] = tweets_df['id'].apply(int)
tweets_df.head()
# Out:
#             id  \
# 0  22662042404
# 1  22662135903
# 2  22662138503
# 3  22662142404
# 4  22662229101
#
#                                                                                                                                           text
# 0  Can someone please tell me WTF the Seahawks are doing? retards
# 1  Q&A with Todd Haley - 8/31 NFL chiefs
# 2  PFW Blog: Bodden done for the year NFL patriots
# 3  Bomar the backup for Giants, for now NFL giants
# 4  Packers made the right moves 2day. Tough decisions in week 7, but Peprah will help ST's & Starks may b ready by then, which would b a boost

# %%
data_header_list = ["id", "tweet_time","team","opponent", "week", "home_or_away","score","opponent_score","point_spread","over_under"]
data_df = pd.read_csv('nfl-tweets-v1.0/tweets.nfl.'+year+'.weekly.csv', names=data_header_list)
data_df.head()
# Out:
#             id          tweet_time team opponent  week home_or_away  score  \
# 0  22662042404  2010-9-01T00:18:50  SEA  SF       1     HOME         31
# 1  22662135903  2010-9-01T00:20:06  KC   SD       1     HOME         21
# 2  22662138503  2010-9-01T00:20:08  NE   CIN      1     HOME         38
# 3  22662142404  2010-9-01T00:20:11  NYG  CAR      1     HOME         31
# 4  22662225702  2010-9-01T00:21:18  DEN  JAX      1     AWAY         17
#
#    opponent_score  point_spread  over_under
# 0  6               3.0           37.0
# 1  14              5.0           44.5
# 2  24             -5.5           44.5
# 3  18             -6.0           41.0
# 4  24              3.0           41.0

# %% [markdown]
# # Step 2: Add Sentiment

# %%
combined_df = pd.merge(data_df,tweets_df,on='id').dropna()
combined_df.head()
# Out:
#             id          tweet_time team opponent  week home_or_away  score  \
# 0  22662042404  2010-9-01T00:18:50  SEA  SF       1     HOME         31
# 1  22662135903  2010-9-01T00:20:06  KC   SD       1     HOME         21
# 2  22662138503  2010-9-01T00:20:08  NE   CIN      1     HOME         38
# 3  22662142404  2010-9-01T00:20:11  NYG  CAR      1     HOME         31
# 4  22662229101  2010-9-01T00:21:20  GB   PHI      1     AWAY         27
#
#    opponent_score  point_spread  over_under  \
# 0  6               3.0           37.0
# 1  14              5.0           44.5
# 2  24             -5.5           44.5
# 3  18             -6.0           41.0
# 4  20             -3.0           48.0
#
#                                                                                                                                           text
# 0  Can someone please tell me WTF the Seahawks are doing? retards
# 1  Q&A with Todd Haley - 8/31 NFL chiefs
# ...

# %%
sent_df = add_sentiment(combined_df)

# %% [markdown]
# # Step 3: Extract Weekly Average Sentiment

# %%
final_df = sent_df[["team", "week","sentiment","text"]]
final_df = final_df.groupby(['team','week'],as_index=False)['sentiment'].mean()

# %%
final_df.to_csv("2010sentiment.csv",index=False)

# %%
final_df.head()
# Out:
#   team  week  sentiment
# 0  ARI  1     0.180404
# 1  ARI  2     0.116099
# 2  ARI  3     0.088700
# 3  ARI  4     0.192257
# 4  ARI  5     0.057983

# %%
final_df
# Out:
#     team  week  sentiment
# 0    ARI  1     0.180404
# 1    ARI  2     0.116099
# 2    ARI  3     0.088700
# 3    ARI  4     0.192257
# 4    ARI  5     0.057983
# ..   ... ..          ...
# 507  WAS  13    0.121189
# 508  WAS  14    0.080666
# 509  WAS  15    0.051873
# 510  WAS  16    0.105535
# 511  WAS  17    0.191555
#
# [512 rows x 3 columns]
